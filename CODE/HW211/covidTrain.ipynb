# %%
import csv

# %%
f = open('covidTrain.csv', 'r')
rdr = csv.reader(f)
for line in rdr:
    print(line)
f.close()

# %%
rdr = csv.DictReader(open('covidTrain.csv'))
print(rdr.fieldnames)
print(','.join(rdr.fieldnames))
# Out:
# ['ID', 'age', 'sex', 'city', 'province', 'country', 'latitude', 'longitude', 'date_onset_symptoms', 'date_admission_hospital', 'date_confirmation', 'symptoms']
# ID,age,sex,city,province,country,latitude,longitude,date_onset_symptoms,date_admission_hospital,date_confirmation,symptoms

# %%
with open('covidTrain.csv') as covidTrain:
    reader = csv.reader(covidTrain)
    next(reader)                          

    for num,row in enumerate(reader):
        if len(row[1]) > 2:
            ave = row[1].split('-')
            ave2 = round((int(ave[0]) + int(ave[1])) /2)
            print(ave2)
# Out:
# 44
# 64
# 64
# 64
# 60
# 64
# 5
# 5
# 34
# 74

# %%
with open('covidTrain.csv') as covidTrain:
    reader = csv.reader(covidTrain)
    next(reader)                          

    for num,row in enumerate(reader):
        date1 = row[8].split('.')
        newdate1 = (date[1] + '.' + date[0] + '.' + date[2])
        date2 = row[9].split('.')
        newdate2 = (date[1] + '.' + date[0] + '.' + date[2])
        date3 = row[10].split('.')
        newdate3 = (date[1] + '.' + date[0] + '.' + date[2])
        
with open('covidTrain.csv') as newcovid:
    writer = csv.writer(newcovid)
# Out:
# 02.19.2020
# 02.19.2020
# 02.19.2020
# 02.17.2020
# 02.13.2020
# 02.19.2020
# 01.19.2020
# 01.22.2020
# 01.18.2020
# 01.22.2020
# 01.18.2020
# 01.19.2020
# 01.21.2020
# 01.19.2020
# 01.18.2020
# 01.19.2020
# 01.18.2020
# 01.21.2020
# 01.23.2020
# 01.22.2020
# 01.22.2020
# 01.24.2020
# 01.21.2020
# 01.26.2020
# 01.30.2020
# 01.24.2020
# 01.28.2020
# 01.25.2020
# 01.24.2020
# 01.20.2020
# 02.03.2020
# 01.14.2020
# 01.30.2020
# 01.29.2020
# 02.01.2020
# 02.02.2020
# 01.24.2020
# 01.29.2020
# 01.22.2020
# 01.30.2020
# 02.03.2020
# 01.22.2020
# 01.20.2020
# 01.21.2020
# 01.22.2020
# 01.19.2020
# 01.17.2020
# 01.19.2020
# 01.19.2020
# 01.19.2020
# 01.16.2020
# 01.20.2020
# 01.09.2020
# 01.14.2020
# 01.18.2020
# 01.16.2020
# 01.28.2020
# 02.01.2020
# 01.24.2020
# 02.01.2020
# 01.24.2020
# 01.21.2020
# 01.19.2020
# 01.24.2020
# 01.24.2020
# 01.28.2020
# 01.26.2020
# 01.28.2020
# 01.23.2020
# 01.24.2020
# 01.27.2020
# 01.23.2020
# 01.24.2020
# 01.30.2020
# 01.28.2020
# 01.21.2020
# 01.29.2020
# 01.28.2020
# 01.29.2020
# 02.04.2020
# 02.10.2020
# 02.07.2020
# 02.03.2020
# 02.05.2020
# 01.30.2020
# 02.01.2020
# 02.06.2020
# 01.25.2020
# 02.07.2020
# 01.16.2020
# 01.03.2020
# 01.13.2020
# 01.02.2020
# 01.08.2020
# 01.01.2020
# 01.04.2020
# 01.10.2020
# 01.26.2020
# 01.29.2020
# 01.16.2020
# 01.28.2020
# 02.02.2020
# 01.28.2020
# 01.30.2020
# 01.25.2020
# 02.07.2020
# 01.13.2020
# 01.19.2020
# 01.30.2020
# 01.21.2020
# 01.20.2020
# 01.21.2020
# 01.23.2020
# 01.19.2020
# 01.22.2020
# 01.22.2020
# 01.09.2020
# 01.14.2020
# 01.22.2020
# 01.19.2020
# 01.21.2020
# 01.19.2020
# 01.22.2020
# 01.20.2020
# 01.23.2020
# 01.15.2020
# 01.22.2020
# 01.18.2020
# 01.14.2020
# 01.31.2020
# 02.15.2020
# 02.18.2020
# 02.17.2020
# 02.17.2020
# 01.19.2020
# 01.24.2020
# 02.03.2020
# 01.31.2020
# 02.08.2020
# 01.22.2020
# 02.13.2020
# 01.25.2020
# 01.21.2020
# 01.28.2020
# 01.22.2020
# 01.19.2020
# 02.01.2020
# 01.25.2020
# 02.12.2020
# 01.23.2020
